# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\joy\Documents\Customers Data Cleaning and Visualization\Customers.csv")
df.head(10)
# Out:
#    CustomerKey Prefix  FirstName LastName              Unnamed: 4 Unnamed: 5  \
# 0        11000    MR.        JON     YANG            MR. JON YANG       YANG
# 1        11001    MR.     EUGENE    HUANG        MR. EUGENE HUANG      HUANG
# 2        11002    MR.      RUBEN   TORRES        MR. RUBEN TORRES     TORRES
# 3        11003    MS.    CHRISTY      ZHU         MS. CHRISTY ZHU        ZHU
# 4        11004   MRS.  ELIZABETH  JOHNSON  MRS. ELIZABETH JOHNSON    JOHNSON
# 5        11005    MR.      JULIO     RUIZ          MR. JULIO RUIZ       RUIZ
# 6        11007    MR.      MARCO    MEHTA         MR. MARCO MEHTA      MEHTA
# 7        11008   MRS.      ROBIN  VERHOFF      MRS. ROBIN VERHOFF    VERHOFF
# 8        11009    MR.    SHANNON  CARLSON     MR. SHANNON CARLSON    CARLSON
# 9        11010    MS.  JACQUELYN   SUAREZ    MS. JACQUELYN SUAREZ     SUAREZ
#
#   Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# 0       YANG    4/8/1966         NaN             M      M
# 1      HUANG  14/05/1965         NaN             S      M
# 2     TORRES   8/12/1965         NaN             M      M
# 3        ZHU  15/02/1968         NaN             S      F
# 4    JOHNSON    8/8/1968         NaN             S      F
# 5       RUIZ    8/5/1965         NaN             S      M
# 6      MEHTA    5/9/1964         NaN             M      M
# 7    VERHOFF    7/7/1964         NaN             S      F
# 8    CARLSON    4/1/1964         NaN             S      M
# 9     SUAREZ    2/6/1964         NaN             S      F
#
#                   EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0        jon24@learnsector.com     $90,000               2      Bachelors
# 1     eugene10@learnsector.com     $60,000               3      Bachelors
# 2      ruben35@learnsector.com     $60,000               3      Bachelors
# 3    christy12@learnsector.com     $70,000               0      Bachelors
# 4   elizabeth5@learnsector.com     $80,000               5      Bachelors
# 5       julio1@learnsector.com     $70,000               0      Bachelors
# 6      marco14@learnsector.com     $60,000               3      Bachelors
# 7         rob4@learnsector.com     $60,000               4      Bachelors
# 8    shannon38@learnsector.com     $70,000               0      Bachelors
# 9  jacquelyn20@learnsector.com     $70,000               0      Bachelors
#
#      Occupation HomeOwner  Unnamed: 17  Unnamed: 18 BirthDate.1
# 0  Professional         Y          NaN          NaN  14-05-1965
# 1  Professional         N          NaN          NaN  15-02-1968
# 2  Professional         Y          NaN          NaN         NaN
# 3  Professional         N          NaN          NaN         NaN
# 4  Professional         Y          NaN          NaN         NaN
# 5  Professional         Y          NaN          NaN         NaN
# 6  Professional         Y          NaN          NaN         NaN
# 7  Professional         Y          NaN          NaN         NaN
# 8  Professional         N          NaN          NaN         NaN
# 9  Professional         N          NaN          NaN         NaN

# %% [markdown]
# # Data Processing and Cleaning

# %%
df.shape
# Out:
# (18148, 20)

# %%
df.columns
# Out:
# Index(['CustomerKey', 'Prefix', 'FirstName', 'LastName', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'BirthDate', 'Unnamed: 8', 'MaritalStatus',
#        'Gender', 'EmailAddress', 'AnnualIncome', 'TotalChildren',
#        'EducationLevel', 'Occupation', 'HomeOwner', 'Unnamed: 17',
#        'Unnamed: 18', 'BirthDate.1'],
#       dtype='object')

# %%
# Dropping some columns by putting them in a list and variable.
x = ['FirstName', 'LastName', 'Unnamed: 18', 'BirthDate.1', 'Unnamed: 8' ]

# %%
df.drop(x, axis = 1, inplace = True)

# %%
df.sample(n=3)
# Out:
#        CustomerKey Prefix        Unnamed: 4 Unnamed: 5 Unnamed: 6   BirthDate  \
# 11854        23089    MR.  MR. LUCAS WALKER     WALKER        NaN  22/11/1977
# 16622        27933   MRS.  MRS. AMBER EVANS      EVANS        NaN  19/02/1954
# 9381         20568    MR.   MR. DUSTIN RAJI       RAJI        NaN  18/06/1946
#
#       MaritalStatus Gender              EmailAddress AnnualIncome  \
# 11854             M      M   lucas37@learnsector.com     $40,000
# 16622             S      F    amber0@learnsector.com     $80,000
# 9381              M      M  dustin21@learnsector.com     $90,000
#
#        TotalChildren   EducationLevel      Occupation HomeOwner  Unnamed: 17
# 11854              0  Partial College  Skilled Manual         Y          NaN
# 16622              3  Partial College    Professional         N          NaN
# 9381               5  Partial College    Professional         N          NaN

# %%
df.drop("Prefix", axis = 1, inplace = True)

# %%
df.shape
# Out:
# (18148, 14)

# %%
df.isna().sum()
# Out:
# CustomerKey           0
# Unnamed: 4            0
# Unnamed: 5            0
# Unnamed: 6        18102
# BirthDate             0
# MaritalStatus         0
# Gender              130
# EmailAddress          0
# AnnualIncome          0
# TotalChildren         0
# EducationLevel        0
# Occupation            0
# HomeOwner             0
# Unnamed: 17       18148
# dtype: int64

# %%
# Dropping the columns with null values
df.drop(['Unnamed: 6', 'Unnamed: 17'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (18148, 12)

# %%
df.isna().sum()
# Out:
# CustomerKey         0
# Unnamed: 4          0
# Unnamed: 5          0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Unnamed: 4      18148 non-null  object
#  2   Unnamed: 5      18148 non-null  object
#  3   BirthDate       18148 non-null  object
#  4   MaritalStatus   18148 non-null  object
#  5   Gender          18018 non-null  object
#  6   EmailAddress    18148 non-null  object
#  7   AnnualIncome    18148 non-null  object
#  8   TotalChildren   18148 non-null  int64
#  9   EducationLevel  18148 non-null  object
#  10  Occupation      18148 non-null  object
#  11  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 1.7+ MB

# %%
# filling the null values
df.fillna(method = 'ffill', inplace = True)

# %%
df.head()
# Out:
#    CustomerKey              Unnamed: 4 Unnamed: 5   BirthDate MaritalStatus  \
# 0        11000            MR. JON YANG       YANG    4/8/1966             M
# 1        11001        MR. EUGENE HUANG      HUANG  14/05/1965             S
# 2        11002        MR. RUBEN TORRES     TORRES   8/12/1965             M
# 3        11003         MS. CHRISTY ZHU        ZHU  15/02/1968             S
# 4        11004  MRS. ELIZABETH JOHNSON    JOHNSON    8/8/1968             S
#
#   Gender                EmailAddress AnnualIncome  TotalChildren  \
# 0      M       jon24@learnsector.com     $90,000               2
# 1      M    eugene10@learnsector.com     $60,000               3
# 2      M     ruben35@learnsector.com     $60,000               3
# 3      F   christy12@learnsector.com     $70,000               0
# 4      F  elizabeth5@learnsector.com     $80,000               5
#
#   EducationLevel    Occupation HomeOwner
# 0      Bachelors  Professional         Y
# 1      Bachelors  Professional         N
# 2      Bachelors  Professional         Y
# 3      Bachelors  Professional         N
# 4      Bachelors  Professional         Y

# %%
df.isna().sum()
# Out:
# CustomerKey       0
# Unnamed: 4        0
# Unnamed: 5        0
# BirthDate         0
# MaritalStatus     0
# Gender            0
# EmailAddress      0
# AnnualIncome      0
# TotalChildren     0
# EducationLevel    0
# Occupation        0
# HomeOwner         0
# dtype: int64

# %%
# Renaming the Unnamed 4 column.
df.rename(columns = {"Unnamed: 4" : "Full Name"}, inplace = True)

# %%
df.head(3)
# Out:
#    CustomerKey         Full Name Unnamed: 5   BirthDate MaritalStatus Gender  \
# 0        11000      MR. JON YANG       YANG    4/8/1966             M      M
# 1        11001  MR. EUGENE HUANG      HUANG  14/05/1965             S      M
# 2        11002  MR. RUBEN TORRES     TORRES   8/12/1965             M      M
#
#                EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0     jon24@learnsector.com     $90,000               2      Bachelors
# 1  eugene10@learnsector.com     $60,000               3      Bachelors
# 2   ruben35@learnsector.com     $60,000               3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %%
df.drop("Unnamed: 5", axis = 1, inplace=True)

# %%
df.head(3)
# Out:
#    CustomerKey         Full Name   BirthDate MaritalStatus Gender  \
# 0        11000      MR. JON YANG    4/8/1966             M      M
# 1        11001  MR. EUGENE HUANG  14/05/1965             S      M
# 2        11002  MR. RUBEN TORRES   8/12/1965             M      M
#
#                EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0     jon24@learnsector.com     $90,000               2      Bachelors
# 1  eugene10@learnsector.com     $60,000               3      Bachelors
# 2   ruben35@learnsector.com     $60,000               3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %%
# Annual income is seen as a text (object)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  object
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  object
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.5+ MB

# %%
df.AnnualIncome.head()
# Out:
# 0    $90,000
# 1    $60,000
# 2    $60,000
# 3    $70,000
# 4    $80,000
# Name: AnnualIncome, dtype: object

# %%
# stripping off the dollar sign
df.AnnualIncome = df.AnnualIncome.str.strip("$")

# %%
df.AnnualIncome.head()
# Out:
# 0    90,000
# 1    60,000
# 2    60,000
# 3    70,000
# 4    80,000
# Name: AnnualIncome, dtype: object

# %%
df.AnnualIncome.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18148 entries, 0 to 18147
# Series name: AnnualIncome
# Non-Null Count  Dtype
# --------------  -----
# 18148 non-null  object
# dtypes: object(1)
# memory usage: 141.9+ KB

# %%
df.AnnualIncome = df.AnnualIncome.str.replace(",","")

# %%
df.AnnualIncome.head()
# Out:
# 0    90000
# 1    60000
# 2    60000
# 3    70000
# 4    80000
# Name: AnnualIncome, dtype: object

# %%
# changing the data type
df.AnnualIncome = df.AnnualIncome.astype(int)
df.AnnualIncome.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18148 entries, 0 to 18147
# Series name: AnnualIncome
# Non-Null Count  Dtype
# --------------  -----
# 18148 non-null  int32
# dtypes: int32(1)
# memory usage: 71.0 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  object
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: int32(1), int64(2), object(8)
# memory usage: 1.5+ MB

# %%
# changing the datatype of date to datetime
df.BirthDate = pd.to_datetime(df.BirthDate, format="%d/%m/%Y")
df.BirthDate
# Out:
# 0       1966-08-04
# 1       1965-05-14
# 2       1965-12-08
# 3       1968-02-15
# 4       1968-08-08
#            ...
# 18143   1958-04-07
# 18144   1960-10-11
# 18145   1960-05-01
# 18146   1959-05-03
# 18147   1959-08-12
# Name: BirthDate, Length: 18148, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  datetime64[ns]
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(2), object(7)
# memory usage: 1.5+ MB

# %%
# Replacing value
df.MaritalStatus = df.MaritalStatus.replace({
    "M" : "Married",
    "S" : "Single"
})
df.MaritalStatus.head()
# Out:
# 0    Married
# 1     Single
# 2    Married
# 3     Single
# 4     Single
# Name: MaritalStatus, dtype: object

# %%
df.Gender = df.Gender.replace({
    "M" : "Male", 
    "F" : "Female"
})
df.Gender.head()
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# 4    Female
# Name: Gender, dtype: object

# %%
df.HomeOwner = df.HomeOwner.replace({
    "Y" : "Yes",
    "N" : "No"
})
df.HomeOwner.tail()
# Out:
# 18143    Yes
# 18144    Yes
# 18145     No
# 18146    Yes
# 18147    Yes
# Name: HomeOwner, dtype: object

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Count of Customers by Marital Status.

# %%
# Count of Customers by Marital Status.
df.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married    9817
# Single     8331
# Name: count, dtype: int64

# %%
df.MaritalStatus.value_counts().plot(kind = "barh", color = ["#e9724d", "#d6d727" ])
plt.title("Count of Customers by Marital Status")
plt.xlabel("Counts")
plt.ylabel("Marital Status")
# Out:
# Text(0, 0.5, 'Marital Status')

# %% [markdown]
# # The proportion of customers by Gender using a pie chart

# %%
df.Gender.value_counts().plot(kind = "pie", startangle=0)
plt.title("Proportion of Customers by Gender")
# Out:
# Text(0.5, 1.0, 'Proportion of Customers by Gender')

# %% [markdown]
# # Generating a histogram of Annual Income to examine its distribution

# %%
# Visualization using seaborn
sns.histplot(data=df, x='AnnualIncome', color='Skyblue', linewidth=1, label='Annual Income')
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income ($)')
plt.ylabel('Frequency')
plt.legend()

# %% [markdown]
# # The average number of TotalChildren for each EducationLevel

# %%
# Calculating the average number of TotalChildren
avg_num_children = df.groupby('EducationLevel')['TotalChildren'].mean().reset_index()
avg_num_children
# Out:
#         EducationLevel  TotalChildren
# 0            Bachelors       1.884243
# 1      Graduate Degree       1.906240
# 2          High School       1.947856
# 3      Partial College       1.748087
# 4  Partial High School       1.668167

# %%
# Visualizing the average number of TotalChildren for each EducationLevel
plt.figure(figsize=(8,6))
sns.barplot(data=avg_num_children, x= 'EducationLevel', y='TotalChildren')
plt.title('Average number of TotalChildren by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average number of TotalChildren')
# Out:
# Text(0, 0.5, 'Average number of TotalChildren')

# %% [markdown]
# # The average AnnualIncome across different Occupation categories.

# %%
df['Occupation'].unique()
# Out:
# array(['Professional', 'Management', 'Skilled Manual', 'Clerical',
#        'Manual'], dtype=object)

# %%
# calculating the total sum of AnnualIncome for each Occupation
df.groupby('Occupation')['AnnualIncome'].sum()
# Out:
# Occupation
# Clerical           87760000
# Management        277670000
# Manual             38760000
# Professional      402280000
# Skilled Manual    232850000
# Name: AnnualIncome, dtype: int32

# %%
# Calculating the average Annual Income for each Occupation.
avg_income = df.groupby('Occupation')['AnnualIncome'].mean().reset_index()
avg_income
# Out:
#        Occupation  AnnualIncome
# 0        Clerical  30696.047569
# 1      Management  92218.532049
# 2          Manual  16472.588185
# 3    Professional  74166.666667
# 4  Skilled Manual  51732.948234

# %%
# Visualizing the average income of each occupation
sns.barplot(data = avg_income, x = 'Occupation', y = 'AnnualIncome')
plt.title("Average Annual Income by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Average Annual Income")
# Out:
# Text(0, 0.5, 'Average Annual Income')

# %% [markdown]
# # Count of customers in each Occupation category using a pie chart.

# %%
# Calcualting the Count of Customers in each Occupation Category
df['Occupation'].value_counts()
# Out:
# Occupation
# Professional      5424
# Skilled Manual    4501
# Management        3011
# Clerical          2859
# Manual            2353
# Name: count, dtype: int64

# %%
plt.title("Count of Customers by Occupation")
df['Occupation'].value_counts().plot(kind='pie', shadow=True, autopct='%0.0f%%', explode=[0,0,0.2,0,0])
plt.xlabel("Count")
plt.ylabel("Occupation")
# Out:
# Text(0, 0.5, 'Occupation')

# %% [markdown]
# # The age distribution of customers

# %%
# Converting date column to datetime, by first defining the possible formats
# Trying to parse with each format
# This code iterates over the list of formats, attempting to parse the date column with each format. 
# If parsing succeeds, it breaks out of the loop. This way, it can handle multiple date formats in the column.
from datetime import datetime
formats = ['%m/%d/%Y', '%d/%m/%Y']
for fmt in  formats:
    try:
        df['BirthDate'] = pd.to_datetime(df['BirthDate'], format=fmt)
        break
    except ValueError:
        pass # if parsing fails, try the next format

# Calculating Age from Datetime
current_date = datetime.now()
df['Age'] = current_date.year - df['BirthDate'].dt.year
df['Age'].head()
# Out:
# 0    58
# 1    59
# 2    59
# 3    56
# 4    56
# Name: Age, dtype: int32

# %%
# Plotting the histogram
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.hist(df['Age'], color = 'Skyblue', bins = 10, edgecolor='black', alpha=0.7)
plt.figure(figsize=(8, 6))

# %% [markdown]
# #  Changes in the average AnnualIncome over different age groups.

# %%
# Defining the age groups
# Defining the age bins
# Defining the labels for age groups
bins = [0, 50, 60, 70, 80, 90, 100, 110]
labels = ['0-50', '51-70', '71-80', '81-90', '91-100', '101-110', '111-120']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
# Calculating the average annual income for the age groups
avg_income_by_age_groups = df.groupby('AgeGroup')['AnnualIncome'].mean()
avg_income_by_age_groups
# Out:
# AgeGroup
# 0-50       35503.144654
# 51-70      57610.324729
# 71-80      62510.929481
# 81-90      62870.611183
# 91-100     59646.539028
# 101-110    54308.510638
# 111-120    28461.538462
# Name: AnnualIncome, dtype: float64

# %%
# Plotting line chart
avg_income_by_age_groups.plot(kind = 'line', marker="*")
plt.title("Average Annual Income over different Age Groups")
plt.xlabel('Age Group')
plt.ylabel("Average Annual Income ($)")
plt.grid(True)

# %% [markdown]
# #  A Bar Chart that shows Home Owner Status

# %%
df['HomeOwner'].value_counts()
# Out:
# HomeOwner
# Yes    12260
# No      5888
# Name: count, dtype: int64

# %%
df['HomeOwner'].value_counts().plot(kind = 'barh')
plt.title("Home Owner Status")
plt.xlabel("Frequency")
plt.ylabel("Home Owner")
plt.legend()

# %% [markdown]
# # The total number of customers by Education Level.

# %%
df['EducationLevel'].value_counts().plot(kind="bar", color=['Blue', 'Orange', 'green', 'purple'])
plt.title("Total Number of Customers by Education Level")
# Out:
# Text(0.5, 1.0, 'Total Number of Customers by Education Level')

# %% [markdown]
# #  The distribution of Total Children using a histogram.

# %%
# PLotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(df['TotalChildren'], edgecolor='gray')
plt.title("Distribution of Total Children")
plt.xlabel("Number of Children")
plt.ylabel("Fequency")
plt.grid(False)

# %% [markdown]
# # A pie chart showing the proportion of different MaritalStatus categories within a specific Occupation.

# %%
# The proportion of different Marital Status categories within a specific occupation.
df.groupby('MaritalStatus')['Occupation'].value_counts().reset_index()
# Out:
#   MaritalStatus      Occupation  count
# 0       Married    Professional   3062
# 1       Married  Skilled Manual   2669
# 2       Married      Management   1888
# 3       Married        Clerical   1407
# 4       Married          Manual    791
# 5        Single    Professional   2362
# 6        Single  Skilled Manual   1832
# 7        Single          Manual   1562
# 8        Single        Clerical   1452
# 9        Single      Management   1123

# %%
df.groupby('MaritalStatus')['Occupation'].value_counts().plot(kind = "pie", autopct='%0.0f%%')
plt.title("Proportion of Different Marital Status within Specific Occupation")
# Out:
# Text(0.5, 1.0, 'Proportion of Different Marital Status within Specific Occupation')

# %% [markdown]
# #  A bar chart comparing the count of male vs. female customers in each EducationLevel.

# %%
# Calculating the counts of female vs male Gender for each Educational Level
df.groupby(['EducationLevel', 'Gender']).size().unstack()
# Out:
# Gender               Female  Male
# EducationLevel
# Bachelors              2584  2677
# Graduate Degree        1581  1544
# High School            1563  1678
# Partial College        2482  2484
# Partial High School     749   806

# %%
# Plotting the Bar Chart
df.groupby(['EducationLevel', 'Gender']).size().plot(kind="bar")
plt.title("The comparison of Genders in each Educational Level")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # The average number of TotalChildren across different income ranges.

# %%
# getting the unique values of the AnnualIncome
df['AnnualIncome'].unique()
# Out:
# array([ 90000,  60000,  70000,  80000, 100000,  30000,  20000,  40000,
#         10000, 160000, 170000, 120000, 130000, 110000, 150000,  50000])

# %%
# Defining the income range
bins = [0, 50000, 80000, 130000, 180000]
labels = ['< 50000', '51000 - 90000', '91000 - 120000', '> 120000']

# %%
# Assigning the income range to each row
df['IncomeRange'] = pd.cut(df['AnnualIncome'], bins=bins, labels=labels, right=False)
df['IncomeRange']
# Out:
# 0        91000 - 120000
# 1         51000 - 90000
# 2         51000 - 90000
# 3         51000 - 90000
# 4        91000 - 120000
#               ...
# 18143           < 50000
# 18144           < 50000
# 18145           < 50000
# 18146           < 50000
# 18147           < 50000
# Name: IncomeRange, Length: 18148, dtype: category
# Categories (4, object): ['< 50000' < '51000 - 90000' < '91000 - 120000' < '> 120000']

# %%
# Calculating the average number of Total Children for each Income range
avg_children_by_income = df.groupby('IncomeRange')['TotalChildren'].mean()
avg_children_by_income
# Out:
# IncomeRange
# < 50000           1.349052
# 51000 - 90000     2.110321
# 91000 - 120000    2.407492
# > 120000          2.187266
# Name: TotalChildren, dtype: float64

# %%
# Plotting the line chart
avg_children_by_income.plot(kind = 'line', marker='o', linestyle = '-')
plt.title("Average Number of Total Children by Income Range")
plt.xlabel("Income Range")
plt.ylabel("Average Number of Children")
# Out:
# Text(0, 0.5, 'Average Number of Children')

# %% [markdown]
# # A column chart that shows the count of customers by HomeOwner status for each MaritalStatus

# %%
df.groupby(['MaritalStatus', 'HomeOwner']).size().reset_index()
# Out:
#   MaritalStatus HomeOwner     0
# 0       Married        No  1816
# 1       Married       Yes  8001
# 2        Single        No  4072
# 3        Single       Yes  4259

# %%
df.groupby(['MaritalStatus', 'HomeOwner']).size().plot(kind = 'bar')
plt.title("The count of Home Owner Status for each Marital Status")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # The distribution of customers' birth months using a bar chart

# %%
# Extracting the birth month
df['Month'] = df['BirthDate'].dt.month
df['Month']
# Out:
# 0         8
# 1         5
# 2        12
# 3         2
# 4         8
#          ..
# 18143     4
# 18144    10
# 18145     5
# 18146     5
# 18147     8
# Name: Month, Length: 18148, dtype: int32

# %%
# Counting the occurrences of each birth month
birth_month = df['Month'].value_counts().sort_index()
birth_month
# Out:
# Month
# 1      831
# 2     1578
# 3     1649
# 4     1617
# 5     1607
# 6     1618
# 7     1502
# 8     1635
# 9     1565
# 10    1672
# 11    1709
# 12    1165
# Name: count, dtype: int64

# %%
# Plotting the bar chart
birth_month.plot(kind = 'bar')
plt.title("Distribution of Birth Month")
plt.xlabel("Month")
plt.ylabel("Number of Customers")
# Out:
# Text(0, 0.5, 'Number of Customers')

# %% [markdown]
# # The proportion of customers by Occupation within a specific income range.

# %%
# Defining the income range
income_range = '20000 - 130000'

# %%
# Filtering the DataFrame for customers within the income range
df_range = df[(df['AnnualIncome'] >= 20000) & (df['AnnualIncome'] <= 130000)]
df_range.head()
# Out:
#    CustomerKey               Full Name  BirthDate MaritalStatus  Gender  \
# 0        11000            MR. JON YANG 1966-08-04       Married    Male
# 1        11001        MR. EUGENE HUANG 1965-05-14        Single    Male
# 2        11002        MR. RUBEN TORRES 1965-12-08       Married    Male
# 3        11003         MS. CHRISTY ZHU 1968-02-15        Single  Female
# 4        11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single  Female
#
#                  EmailAddress  AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@learnsector.com         90000              2      Bachelors
# 1    eugene10@learnsector.com         60000              3      Bachelors
# 2     ruben35@learnsector.com         60000              3      Bachelors
# 3   christy12@learnsector.com         70000              0      Bachelors
# 4  elizabeth5@learnsector.com         80000              5      Bachelors
#
#      Occupation HomeOwner  Age AgeGroup     IncomeRange  Month
# 0  Professional       Yes   58    51-70  91000 - 120000      8
# 1  Professional        No   59    51-70   51000 - 90000      5
# 2  Professional       Yes   59    51-70   51000 - 90000     12
# 3  Professional        No   56    51-70   51000 - 90000      2
# 4  Professional       Yes   56    51-70  91000 - 120000      8

# %%
# Counting the occurrences of each occupation within each income range
occp_counts = df_range['Occupation'].value_counts()
occp_counts
# Out:
# Occupation
# Professional      5328
# Skilled Manual    4465
# Management        2807
# Clerical          2775
# Manual            1338
# Name: count, dtype: int64

# %%
# Plotting the pie chart
occp_counts.plot(kind='pie', autopct='%0.0f%%')
plt.title("The Proportion of Customers by Occupation within a Specific Income range")
# Out:
# Text(0.5, 1.0, 'The Proportion of Customers by Occupation within a Specific Income range')

# %% [markdown]
# # The frequency of each EducationLevel category.

# %%
df['EducationLevel'].value_counts().plot(kind='bar', color="skyblue")
plt.title("Frequency of each Education Level ")
plt.xlabel("Education Level")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
